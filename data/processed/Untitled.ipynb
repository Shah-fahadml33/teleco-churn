# %%
import os
os.chdir(r"D:\teleco-churn-project\teleco-churn")
from pathlib import Path
from src.train import train_model,save_model,load_model,save_eval_outputs
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier,BaggingClassifier,GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from src.evaluate_1 import eval_model,cross_validation,save_eval_outputs
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 4
#       2 os.chdir(r"D:\teleco-churn-project\teleco-churn")
#       3 from pathlib import Path
# ----> 4 from src.train import train_model,save_model,load_model,save_eval_outputs
#       5 from sklearn.model_selection import train_test_split
#       6 from sklearn.linear_model import LogisticRegression
#
# ImportError: cannot import name 'save_eval_outputs' from 'src.train' (D:\teleco-churn-project\teleco-churn\src\train.py)

# %%
data=pd.read_csv("data/processed/processed_data.csv")

# %%
x=data.drop(['churn'],axis=1)
y=data['churn']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42 ,shuffle=True)

# %%
logistic_model=train_model(LogisticRegression(class_weight='balanced'),x_train,y_train)

# %%
eval_model(logistic_model,x_test,y_test,model_name='Logistic Regression Model')

# %%
sa
